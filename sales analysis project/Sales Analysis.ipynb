# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading dataset

# %%
df1 = pd.read_csv(r"C:\Users\intel\Downloads\datasets\supermarket.csv")
df1
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9795    SH-19975     Sally Hughsby  Corporate  United States          Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
#
#            State  Postal Code   Region       Product ID         Category  \
# 0       Kentucky      42420.0    South  FUR-BO-10001798        Furniture
# 1       Kentucky      42420.0    South  FUR-CH-10000454        Furniture
# 2     California      90036.0     West  OFF-LA-10000240  Office Supplies
# 3        Florida      33311.0    South  FUR-TA-10000577        Furniture
# 4        Florida      33311.0    South  OFF-ST-10000760  Office Supplies
# ...          ...          ...      ...              ...              ...
# 9795    Illinois      60610.0  Central  OFF-BI-10003429  Office Supplies
# 9796        Ohio      43615.0     East  OFF-AR-10001374  Office Supplies
# 9797        Ohio      43615.0     East  TEC-PH-10004977       Technology
# 9798        Ohio      43615.0     East  TEC-PH-10000912       Technology
# 9799        Ohio      43615.0     East  TEC-AC-10000487       Technology
#
#      Sub-Category                                       Product Name     Sales
# 0       Bookcases                  Bush Somerset Collection Bookcase  261.9600
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2          Labels  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4         Storage                     Eldon Fold 'N Roll Cart System   22.3680
# ...           ...                                                ...       ...
# 9795      Binders  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796          Art           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797       Phones                                        GE 30524EE4  235.1880
# 9798       Phones           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799  Accessories                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9800 rows x 18 columns]

# %%
df2 = df1.copy()

# %% [markdown]
# ## Sales Distribution by Category and Sub-Category:

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
df2['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
plt.figure(figsize = (10,6))
ax = sns.countplot(x = df2['Category'])
for i in ax.containers:
    ax.bar_label(i)
plt.title("Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Category counts")
plt.show()

# %% [markdown]
# In "Category" distribution Office supplies has most sales.

# %%
# Sales by sub-category
plt.figure(figsize = (10,6))
ax = sns.countplot(x = df2['Sub-Category'])
for i in ax.containers:
    ax.bar_label(i)
plt.title("Distribution by Sub-Category")
plt.xlabel("Sub-Category")
plt.ylabel("SubCategory counts")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# In Sub-category distribution "Binders" has most sales.

# %% [markdown]
# ## Sales Trend Over Time:

# %%
df2.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9656    9657  CA-2015-156160 2015-09-22 2015-09-29  Standard Class
# 6498    6499  CA-2016-103135 2016-07-24 2016-07-28  Standard Class
# 1791    1792  CA-2015-120474 2015-12-01 2015-12-03     First Class
# 1444    1445  CA-2017-133725 2017-05-23 2017-05-28  Standard Class
# 9417    9418  CA-2015-148285 2015-10-27 2015-11-01  Standard Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 9656    AS-10090  Adam Shillingsburg     Consumer  United States
# 6498    SS-20515     Shirley Schmidt  Home Office  United States
# 1791    RP-19390        Resi Pölking     Consumer  United States
# 1444    KL-16645        Ken Lonsdale     Consumer  United States
# 9417    RD-19810    Ross DeVincentis  Home Office  United States
#
#                City  ... Postal Code   Region       Product ID  \
# 9656  New York City  ...     10035.0     East  OFF-BI-10003355
# 6498     Louisville  ...     40214.0    South  OFF-BI-10000069
# 1791        Madison  ...     53711.0  Central  FUR-CH-10001854
# 1444        Chicago  ...     60623.0  Central  TEC-PH-10004165
# 9417   Fayetteville  ...     28314.0    South  OFF-PA-10001166
#
#              Category Sub-Category  \
# 9656  Office Supplies      Binders
# 6498  Office Supplies      Binders
# 1791        Furniture       Chairs
# 1444       Technology       Phones
# 9417  Office Supplies        Paper
#
#                                            Product Name     Sales  \
# 9656              Cardinal Holdit Business Card Pockets     3.984
# 6498  GBC Prepunched Paper, 19-Hole, for Binding Sys...   135.090
# 1791  Office Star - Professional Matrix Back Chair w...  2807.840
# 1444                       Mitel MiVoice 5330e IP Phone  1979.928
# 9417                                            Xerox 2    10.368
#
#       orders_by_years  orders_by_months  Shipping Time (Days)
# 9656             2015                 9                     7
# 6498             2016                 7                     4
# 1791             2015                12                     2
# 1444             2017                 5                     5
# 9417             2015                10                     5
#
# [5 rows x 21 columns]

# %%
l = []
l2 = []
for i in df2['Order Date']:
    l1.append(int(i[6:]))
    l2.append(int(i[3:5]))

# %%
df2['orders_by_years'] = l

# %%
df2['orders_by_months'] = l2

# %%
df2.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4842    4843  CA-2018-118402  29/09/2018  04/10/2018  Standard Class
# 3424    3425  CA-2017-134803  28/05/2017  03/06/2017  Standard Class
# 7250    7251  CA-2016-158491  04/06/2016  09/06/2016    Second Class
# 8941    8942  CA-2017-159023  03/11/2017  05/11/2017     First Class
# 2110    2111  CA-2016-164882  31/10/2016  31/10/2016        Same Day
#
#      Customer ID   Customer Name   Segment        Country         City  \
# 4842    JO-15280   Jas O'Carroll  Consumer  United States      Memphis
# 3424    CL-12565     Clay Ludtke  Consumer  United States  Los Angeles
# 7250    BP-11155       Becky Pak  Consumer  United States  Los Angeles
# 8941    NW-18400  Natalie Webber  Consumer  United States     Portland
# 2110    SG-20080  Sandra Glassco  Consumer  United States     Redlands
#
#            State  Postal Code Region       Product ID         Category  \
# 4842   Tennessee      38109.0  South  OFF-ST-10001418  Office Supplies
# 3424  California      90004.0   West  TEC-MA-10001972       Technology
# 7250  California      90008.0   West  TEC-AC-10003870       Technology
# 8941      Oregon      97206.0   West  OFF-BI-10002813  Office Supplies
# 2110  California      92374.0   West  OFF-FA-10000585  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# 4842      Storage     Carina Media Storage Towers in Natural & Black  243.920
# 3424     Machines                             Okidata C331dn Printer  558.400
# 7250  Accessories  Logitech Z-906 Speaker sys - home theater - 5....  989.970
# 8941      Binders          Avery Reinforcements for Hole-Punch Pages    4.158
# 2110    Fasteners                   OIC Bulk Pack Metal Binder Clips   17.450
#
#       orders_by_years  orders_by_months
# 4842             2018                 9
# 3424             2017                 5
# 7250             2016                 6
# 8941             2017                11
# 2110             2016                10

# %%
#Distribution by order year
plt.figure(figsize = (10,6))
ax = sns.countplot(x = df2['orders_by_years'])
for i in ax.containers:
    ax.bar_label(i)
plt.title("Distribution by order year")
plt.xlabel("order years")
plt.ylabel("order year counts")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Most of the sales are in the year "2018"

# %%
# Sales by months
plt.figure(figsize = (10,6))
ax = sns.countplot(x = df2['orders_by_months'])
for i in ax.containers:
    ax.bar_label(i)
plt.title("Distribution by order months")
plt.xlabel("order months")
plt.ylabel("order months counts")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Most of the sales are in "November".

# %% [markdown]
# ## Customer Segments and Sales:

# %%
a1 = df2['Segment'].value_counts()

# %%
val = a1.values
ind = a1.index

# %%
plt.pie(val,labels = ind,autopct = "%1.1f%%")
plt.show()

# %% [markdown]
# ## Regional Sales Analysis:

# %%
df2['Region'].value_counts()
# Out:
# Region
# West       3140
# East       2785
# Central    2277
# South      1598
# Name: count, dtype: int64

# %%
val1 = df2['Region'].value_counts().values
ind1 = df2['Region'].value_counts().index

# %%
plt.pie(val1,labels = ind1,autopct = "%1.1f%%")
plt.show()

# %%
# Distribution  by Region
plt.figure(figsize = (10,6))
ax = sns.countplot(x = df2['Region'])
for i in ax.containers:
    ax.bar_label(i)
plt.title("Distribution by Region")
plt.xlabel("Region")
plt.ylabel("Region counts")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Shipping Modes and Sales:

# %%
df2.sample(2)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 5450    5451  US-2015-119081  12/09/2015  19/09/2015  Standard Class
#
#      Customer ID  Customer Name      Segment        Country     City  \
# 9795    SH-19975  Sally Hughsby    Corporate  United States  Chicago
# 5450    TA-21385   Tom Ashbrook  Home Office  United States   Olathe
#
#          State  Postal Code   Region       Product ID         Category  \
# 9795  Illinois      60610.0  Central  OFF-BI-10003429  Office Supplies
# 5450    Kansas      66062.0  Central  OFF-BI-10004519  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# 9795      Binders  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.798
# 5450      Binders           GBC DocuBind P100 Manual Binding Machine  331.960
#
#       orders_by_years  orders_by_months
# 9795             2017                 5
# 5450             2015                 9

# %%
#Shiping mode distribution
plt.figure(figsize = (10,6))
ax = sns.countplot(x = df2['Ship Mode'])
for i in ax.containers:
    ax.bar_label(i)
plt.title("Distribution by Ship Mode")
plt.xlabel("Ship Mode")
plt.ylabel("Ship Mode counts")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# In shiping mode "Standard Class" is in the most of sales.

# %% [markdown]
# ## City and State Sales Performance:

# %%
plt.figure(figsize = (10,10))
ax = sns.countplot(y = df2['State'])
for i in ax.containers:
    ax.bar_label(i)
plt.title("Distribution by State")
plt.xlabel("State")
plt.ylabel("State counts")
plt.xticks(rotation = 90)
plt.show()

# %%
city_count = df2['City'].value_counts()[:10]

# %%
plt.pie(city_count.values,labels = city_count.index, autopct = '%1.1f%%')
plt.show()

# %%
df2['State'].value_counts()[:5]
# Out:
# State
# California      1946
# New York        1097
# Texas            973
# Pennsylvania     582
# Washington       504
# Name: count, dtype: int64

# %% [markdown]
# ## Order and Ship Date Analysis

# %%
df2.sample(4)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 6283    6284  CA-2017-100944  24/09/2017  28/09/2017  Standard Class
# 5420    5421  US-2017-151827  31/03/2017  02/04/2017    Second Class
# 6052    6053  CA-2017-124016  23/09/2017  26/09/2017    Second Class
# 5147    5148  CA-2018-128734  24/12/2018  31/12/2018  Standard Class
#
#      Customer ID    Customer Name      Segment        Country          City  \
# 6283    EH-13765     Edward Hooks    Corporate  United States   Los Angeles
# 5420    CS-11950   Carlos Soltero     Consumer  United States  Philadelphia
# 6052    JS-15940  Joni Sundaresam  Home Office  United States     Lancaster
# 5147    JL-15175     James Lanier  Home Office  United States      Chandler
#
#              State  Postal Code Region       Product ID         Category  \
# 6283    California      90049.0   West  OFF-EN-10001453  Office Supplies
# 5420  Pennsylvania      19134.0   East  TEC-PH-10002789       Technology
# 6052          Ohio      43130.0   East  OFF-PA-10002586  Office Supplies
# 5147       Arizona      85224.0   West  FUR-FU-10001731        Furniture
#
#      Sub-Category                                       Product Name    Sales  \
# 6283    Envelopes  Tyvek Interoffice Envelopes, 9 1/2" x 12 1/2",...  304.900
# 5420       Phones                                           LG Exalt  280.782
# 6052        Paper                                         Xerox 1970   11.952
# 5147  Furnishings                  Acrylic Self-Standing Desk Frames    8.544
#
#       orders_by_years  orders_by_months
# 6283             2017                 9
# 5420             2017                 3
# 6052             2017                 9
# 5147             2018                12

# %%
# Convert Order Date and Ship Date to datetime format
df2['Order Date'] = pd.to_datetime(df2['Order Date'], format='%d/%m/%Y')
df2['Ship Date'] = pd.to_datetime(df2['Ship Date'], format='%d/%m/%Y')

# %%
# Calculate the time difference in days
df2['Shipping Time (Days)'] = (df2['Ship Date'] - df2['Order Date']).dt.days

# %%
# Compute the average shipping time
average_shipping_time = df2['Shipping Time (Days)'].mean()
print(f"The average shipping time is {average_shipping_time:.2f} days.")
# Out:
# The average shipping time is 3.96 days.

# %%
# Plot the distribution of shipping times
plt.figure(figsize=(10, 6))
plt.hist(df2['Shipping Time (Days)'], bins=range(df2['Shipping Time (Days)'].min(), df2['Shipping Time (Days)'].max() + 1), edgecolor='black')
plt.title('Distribution of Shipping Times')
plt.xlabel('Shipping Time (Days)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Analyze patterns and outliers
shipping_time_summary = df2['Shipping Time (Days)'].describe()
print(shipping_time_summary)

# Identify potential outliers (e.g., shipping times significantly higher than the mean)
outliers = df2[df2['Shipping Time (Days)'] > df2['Shipping Time (Days)'].mean() + 3 * df2['Shipping Time (Days)'].std()]
print(f"Number of outliers: {len(outliers)}")
# Out:
# count    9800.000000
# mean        3.961122
# std         1.749614
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         7.000000
# Name: Shipping Time (Days), dtype: float64
# Number of outliers: 0

# %% [markdown]
# ## Top Customers by Sales:

# %%
# Group by customer name and sum the sales
customer_sales = df2.groupby('Customer Name')['Sales'].sum()

# %%
# sort the customer by total sales in descending order
top_customers = customer_sales.sort_values(ascending = False).head(10)

# %%
print("Top 10 Customers by Total Sales:")
print(top_customers)
# Out:
# Top 10 Customers by Total Sales:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
top_10_sales_contribution = top_customers.sum()

# %%
overall_sales = df2['Sales'].sum()

# %%
contibution_percentage = (top_10_sales_contribution / overall_sales) * 100

# %%
print(f"\nTotal sales contribution by the top 10 customers: ${top_10_sales_contribution:.2f}")
print(f"Percentage contribution to overall sales: {contibution_percentage:.2f}%")
# Out:
# Total sales contribution by the top 10 customers: $153811.17
# Percentage contribution to overall sales: 6.80%

# %% [markdown]
# ## Product Performance:

# %%
high_prod = df2.groupby("Product Name")['Sales'].sum()

# %%
# sort the customer by total sales in descending order
top_prod = high_prod.sort_values(ascending = False).head(10)

# %%
top_prod
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
df2.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1222    1223  CA-2017-126004 2017-12-04 2017-12-05     First Class
# 2696    2697  CA-2015-145317 2015-03-18 2015-03-23  Standard Class
# 161      162  CA-2016-119697 2016-12-28 2016-12-31    Second Class
# 9162    9163  CA-2017-160108 2017-12-08 2017-12-12  Standard Class
# 5752    5753  CA-2017-125850 2017-01-22 2017-01-28  Standard Class
#
#      Customer ID  Customer Name      Segment        Country           City  \
# 1222    BM-11140   Becky Martin     Consumer  United States  New York City
# 2696    SM-20320    Sean Miller  Home Office  United States   Jacksonville
# 161     EM-13960   Eric Murdock     Consumer  United States   Philadelphia
# 9162    AG-10900  Arthur Gainer     Consumer  United States     Eau Claire
# 5752    FP-14320    Frank Preis     Consumer  United States      San Diego
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 1222  ...     10024.0     East  FUR-FU-10001602        Furniture  Furnishings
# 2696  ...     32216.0    South  TEC-MA-10003626       Technology     Machines
# 161   ...     19134.0     East  TEC-AC-10003657       Technology  Accessories
# 9162  ...     54703.0  Central  FUR-CH-10002335        Furniture       Chairs
# 5752  ...     92037.0     West  OFF-LA-10004484  Office Supplies       Labels
#
#                                            Product Name    Sales  \
# 1222  Eldon Delta Triangular Chair Mat, 52" x 58", C...  113.790
# 2696  Hewlett-Packard Deskjet 6540 Color Inkjet Printer  821.300
# 161                    Lenovo 17-Key USB Numeric Keypad   54.384
# 9162                             Hon GuestStacker Chair  680.010
# 5752                                          Avery 476   20.650
#
#       orders_by_years  orders_by_months  Shipping Time (Days)
# 1222             2017                12                     1
# 2696             2015                 3                     5
# 161              2016                12                     3
# 9162             2017                12                     4
# 5752             2017                 1                     6
#
# [5 rows x 21 columns]
